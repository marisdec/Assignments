# %% [markdown]
# # Q1

# %% [markdown]
# # a)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Why Libraries are Requried?
#
# Libraries are requried for Data Visualization and graphical representation of small and huge collection of data. It converts a huge dataset into small graphs with in data analysis and predictions.
#
# Matplotlib and Seaborn act as the backbone of data visualization through Python.
#
# Matplotlib - It is utilized for making basic graphs. Datasets are visualised with the help of bargraphs, histograms, piecharts, scatter plots, lines and so on.
#
# Syntax:  matplotlib.pyplot.bar(x_axis, y_axis)
#
# Seaborn - Contains a number of patterns and plots for data visualization. It uses fascinating themes. It helps in compiling whole data into a single plot. It also provides distribution of data.
#
# Syntax:: seaborn.barplot(x_axis, y_axis)

# %% [markdown]
# # b)

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# We can see that the dataframe contains 6 columns and 150 rows.
#
# Now, let’s also the columns and their data types. For this, we will use the info() method.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# We can see that only one column has categorical data and all the other
# columns are of the numeric type with non-Null entries.

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# We can see the count of each column along with their mean value, standard deviation, minimum and maximum values.
#
# By using describe() Method we get the statistical summary of the dataset.
#
# The describe() function applies basic statistical computations on the dataset like extreme values,
# count of data points standard deviation, etc. Any missing value or NaN value is automatically skipped.
#
# describe() function gives a good picture of the distribution of data.

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# We can see that no column as any missing value.

# %% [markdown]
# # c)

# %%
iris = sns.load_dataset("iris")
g = sns.PairGrid(iris)
g.map(sns.scatterplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot)

# %% [markdown]
# Pairgrid represents the relationship between our target and the variables. We can see that the setosa species has a large difference in its characteristics when compared to the other species, it has smaller petal width and length while its sepal width is high and its sepal length is low.

# %% [markdown]
# # d)

# %%
sns.pairplot(iris)
sns.set_style("darkgrid")

# %%
sns.pairplot(iris,hue='species',height=3)
plt.show()

# %% [markdown]
# 1. Petal length and petal width are the most useful features to identify and differentiate various flower types.
# 2. While Setosa can be easily identified as linearly separable. virginica and Versicolor have some overlap and almost linearly separable.
# 3. We can find “lines” and “if-else” conditions to build a simple model to classify the flower types.

# %% [markdown]
# # e)

# %%
g = sns.jointplot(data=iris, x='sepal_length' , y='petal_length', kind = 'hex')
g.plot_marginals(sns.kdeplot)

# %% [markdown]
# As we compare sepal length and petal length observed that petal length are better separable.
#
# There is overlap between vericolor and virginca and we can see virginica & versicolor are fully overlapped.
